# %% [markdown]
# **The** **Sparks** **Foundation** #**GRIPFEB21**
#
# **Prediction** **using** **Decision Tree Algorithm**
#
# **Name** : **Sarikaa** **S**

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
#mounting my google drive where the dataset is present
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# Out:
# Mounted at /content/gdrive

# %%
#reading the dataset
dataset = "/mydrive/Iris.csv"

#read_csv in pandas is used to read the csv file
data = pd.read_csv(dataset)
print("Imported the dataset successfully")
# Out:
# Imported the dataset successfully

# %%
#Printing the shape of the dataset to know the no.of rows and columns
print(data.shape)
data.head()#This line prints the first five rows of the dataset
# Out:
# (150, 6)
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#assigning input features to x and output labels to y
x=data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y=data[['Species']]

# %%
#The dataset is split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1) #80% training set and 20% testing set

# %% [markdown]
# ***Defining the decision tree model and training the model***

# %%
# Create Decision Tree classifer object
tree = DecisionTreeClassifier()

# Train Decision Tree Classifer
tree= tree.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = tree.predict(X_test)

# %% [markdown]
# ***Evaluating the model***

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9666666666666667

# %% [markdown]
# ***For visualizing the Decision tree two libraries graphviz and pydotplus are used.***

# %%
feature=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(tree, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('iris.png')
Image(graph.create_png())

# %% [markdown]
# ***export_graphviz function converts decision tree classifier into dot file and pydotplus convert this dot file to png or displayable form***
